# %%
import matplotlib.pyplot as plt

def draw_pitch(pitch, line, orientation,view):
    
    orientation = orientation
    view = view
    line = line
    pitch = pitch
    
    if orientation.lower().startswith("h"):
        
        if view.lower().startswith("h"):
            fig,ax = plt.subplots(figsize=(6.8,10.4))
            plt.xlim(49,105)
            plt.ylim(-1,69)
        else:
            fig,ax = plt.subplots(figsize=(10.4,6.8))
            plt.xlim(-1,105)
            plt.ylim(-1,69)
        ax.axis('off') # this hides the x and y ticks
    
        # side and goal lines #
        ly1 = [0,0,68,68,0]
        lx1 = [0,104,104,0,0]

        plt.plot(lx1,ly1,color=line,zorder=5)


        # boxes, 6 yard box and goals

            #outer boxes#
        ly2 = [13.84,13.84,54.16,54.16] 
        lx2 = [104,87.5,87.5,104]
        plt.plot(lx2,ly2,color=line,zorder=5)

        ly3 = [13.84,13.84,54.16,54.16] 
        lx3 = [0,16.5,16.5,0]
        plt.plot(lx3,ly3,color=line,zorder=5)

            #goals#
        ly4 = [30.34,30.34,37.66,37.66]
        lx4 = [104,104.2,104.2,104]
        plt.plot(lx4,ly4,color=line,zorder=5)

        ly5 = [30.34,30.34,37.66,37.66]
        lx5 = [0,-0.2,-0.2,0]
        plt.plot(lx5,ly5,color=line,zorder=5)


           #6 yard boxes#
        ly6 = [24.84,24.84,43.16,43.16]
        lx6 = [104,99.5,99.5,104]
        plt.plot(lx6,ly6,color=line,zorder=5)

        ly7 = [24.84,24.84,43.16,43.16]
        lx7 = [0,4.5,4.5,0]
        plt.plot(lx7,ly7,color=line,zorder=5)

        #Halfway line, penalty spots, and kickoff spot
        ly8 = [0,68] 
        lx8 = [52,52]
        plt.plot(lx8,ly8,color=line,zorder=5)


        plt.scatter(93,34,color=line,zorder=5)
        plt.scatter(11,34,color=line,zorder=5)
        plt.scatter(52,34,color=line,zorder=5)

        circle1 = plt.Circle((93.5,34), 9.15,ls='solid',lw=1.5,color=line, fill=False, zorder=1,alpha=1)
        circle2 = plt.Circle((10.5,34), 9.15,ls='solid',lw=1.5,color=line, fill=False, zorder=1,alpha=1)
        circle3 = plt.Circle((52, 34), 9.15,ls='solid',lw=1.5,color=line, fill=False, zorder=2,alpha=1)

        ## Rectangles in boxes
        rec1 = plt.Rectangle((87.5,20), 16,30,ls='-',color=pitch, zorder=1,alpha=1)
        rec2 = plt.Rectangle((0, 20), 16.5,30,ls='-',color=pitch, zorder=1,alpha=1)

        ## Pitch rectangle
        rec3 = plt.Rectangle((-1, -1), 106,70,ls='-',color=pitch, zorder=1,alpha=1)

        ax.add_artist(rec3)
        ax.add_artist(circle1)
        ax.add_artist(circle2)
        ax.add_artist(rec1)
        ax.add_artist(rec2)
        ax.add_artist(circle3)
        
    else:
        if view.lower().startswith("h"):
            fig,ax = plt.subplots(figsize=(10.4,6.8))
            plt.ylim(49,105)
            plt.xlim(-1,69)
        else:
            fig,ax = plt.subplots(figsize=(6.8,10.4))
            plt.ylim(-1,105)
            plt.xlim(-1,69)
        ax.axis('off') # this hides the x and y ticks

        # side and goal lines #
        lx1 = [0,0,68,68,0]
        ly1 = [0,104,104,0,0]

        plt.plot(lx1,ly1,color=line,zorder=5)


        # boxes, 6 yard box and goals

            #outer boxes#
        lx2 = [13.84,13.84,54.16,54.16] 
        ly2 = [104,87.5,87.5,104]
        plt.plot(lx2,ly2,color=line,zorder=5)

        lx3 = [13.84,13.84,54.16,54.16] 
        ly3 = [0,16.5,16.5,0]
        plt.plot(lx3,ly3,color=line,zorder=5)

            #goals#
        lx4 = [30.34,30.34,37.66,37.66]
        ly4 = [104,104.2,104.2,104]
        plt.plot(lx4,ly4,color=line,zorder=5)

        lx5 = [30.34,30.34,37.66,37.66]
        ly5 = [0,-0.2,-0.2,0]
        plt.plot(lx5,ly5,color=line,zorder=5)


           #6 yard boxes#
        lx6 = [24.84,24.84,43.16,43.16]
        ly6 = [104,99.5,99.5,104]
        plt.plot(lx6,ly6,color=line,zorder=5)

        lx7 = [24.84,24.84,43.16,43.16]
        ly7 = [0,4.5,4.5,0]
        plt.plot(lx7,ly7,color=line,zorder=5)

        #Halfway line, penalty spots, and kickoff spot
        lx8 = [0,68] 
        ly8 = [52,52]
        plt.plot(lx8,ly8,color=line,zorder=5)


        plt.scatter(34,93,color=line,zorder=5)
        plt.scatter(34,11,color=line,zorder=5)
        plt.scatter(34,52,color=line,zorder=5)

        circle1 = plt.Circle((34,93.5), 9.15,ls='solid',lw=1.5,color=line, fill=False, zorder=1,alpha=1)
        circle2 = plt.Circle((34,10.5), 9.15,ls='solid',lw=1.5,color=line, fill=False, zorder=1,alpha=1)
        circle3 = plt.Circle((34,52), 9.15,ls='solid',lw=1.5,color=line, fill=False, zorder=2,alpha=1)


        ## Rectangles in boxes
        rec1 = plt.Rectangle((20, 87.5), 30,16.5,ls='-',color=pitch, zorder=1,alpha=1)
        rec2 = plt.Rectangle((20, 0), 30,16.5,ls='-',color=pitch, zorder=1,alpha=1)

        ## Pitch rectangle
        rec3 = plt.Rectangle((-1, -1), 70,106,ls='-',color=pitch, zorder=1,alpha=1)

        ax.add_artist(rec3)
        ax.add_artist(circle1)
        ax.add_artist(circle2)
        ax.add_artist(rec1)
        ax.add_artist(rec2)
        ax.add_artist(circle3)

# %%
draw_pitch("#195905","#faf0e6","h","full")

# %%
 draw_pitch("#195905","#faf0e6","vertical","half")

# %%
import pandas as pd
import numpy as np
from statistics import mean, median

pd.options.display.max_columns = None
pd.options.display.max_rows = None

data = pd.read_csv('Belottishot.csv',encoding="ISO-8859-1")  #data from understat

data['newX'] = (data['X'] * 104)
data['newY'] = (data['Y'] * 68)

x = data['newX']
y = data['newY']
xG = data['xG']

zo = 12
#print(data.head())
# Out:
#       id  minute       result      X      Y        xG          player h_a  \
# 0  41749      75  MissedShots  0.895  0.674  0.058460  Andrea Belotti   a
# 1  42073      68  BlockedShot  0.803  0.522  0.050800  Andrea Belotti   h
# 2  42082      83    SavedShot  0.770  0.672  0.019515  Andrea Belotti   h
# 3  42383       5  BlockedShot  0.908  0.716  0.046230  Andrea Belotti   a
# 4  42387      17         Goal  0.933  0.493  0.062818  Andrea Belotti   a
#
#    player_id   situation  year   shotType  match_id   h_team   a_team  \
# 0       1186    OpenPlay  2014   LeftFoot      5118   Verona  Palermo
# 1       1186    OpenPlay  2014   LeftFoot      5128  Palermo    Inter
# 2       1186    OpenPlay  2014  RightFoot      5128  Palermo    Inter
# 3       1186    OpenPlay  2014   LeftFoot      5135   Napoli  Palermo
# 4       1186  FromCorner  2014       Head      5135   Napoli  Palermo
#
#    h_goals  a_goals                 date player_assisted lastAction  \
# ...

# %%
draw_pitch("#195905","#faf0e6","vertical","half")
y1 = [68 - i for i in y]
z1 = [500 * i for i in xG] # This is to scale the "xG" values for plotting
#plt.scatter(y1,x,c="red",edgecolors="k",zorder=zo)
plt.scatter(y1,x,c="white",edgecolors="k",zorder=zo)
plt.show()

# %%
data_OP = data[((data['situation'] == 'OpenPlay'))]
data_OPG = data[((data['result'] == 'Goal') & (data['situation'] == 'OpenPlay'))]
#data_OPG = data[((data['situation'] == 'OpenPlay'))]
data_OPNG = data_OP[((data_OP['result'] == 'BlockedShot') | (data_OP['result'] == 'ShotOnPost') | (data_OP['result'] == 'SavedShot'))]
data_OPM = data_OP[((data_OP['result'] == 'MissedShots'))]
       
x_OPShots = data_OP['newX']
y_OPShots = data_OP['newY']
xG_OPShots = data_OP['xG']

x_OPG = data_OPG['newX']
y_OPG = data_OPG['newY']
xG_OPG = data_OPG['xG']

x_OPNG = data_OPNG['newX']
y_OPNG = data_OPNG['newY']
xG_OPNG = data_OPNG['xG']
                    
x_OPM = data_OPM['newX']
y_OPM = data_OPM['newY']
xG_OPM = data_OPM['xG']

#print(len(data_OPM))

zo = 12

draw_pitch("#242318","#faf0e6","vertical","half")
y1_OPShots = [68 - i for i in y_OPShots]
z1_OPShots = [500 * i for i in xG_OPShots] # This is to scale the "xG" values for plotting

y1_OPG = [68 - i for i in y_OPG]
z1_OPG = [500 * i for i in xG_OPG] # This is to scale the "xG" values for plotting

y1_OPNG = [68 - i for i in y_OPNG]
z1_OPNG = [500 * i for i in xG_OPNG] # This is to scale the "xG" values for plotting

y1_OPM = [68 - i for i in y_OPM]
z1_OPM = [500 * i for i in xG_OPM] # This is to scale the "xG" values for plotting


if len(data_OPG) > 0: 
    plt.scatter(y1_OPG,x_OPG,s=z1_OPG,c="#b69c0e",edgecolors="white",zorder=zo+1)
#if len(data_OPNG) > 0:
#    plt.scatter(y1_OPNG,x_OPNG,s=z1_OPNG,c="white",edgecolors="k",zorder=zo)
if len(data_OPM) > 0:
    plt.scatter(y1_OPM,x_OPM,s=z1_OPM,c="#d40808",edgecolors="white",zorder=zo)
     
        
mSize = [0.05,0.10,0.2,0.4,0.6,1] 
mSizeS = [500 * i for i in mSize]
mx = [5.5,7,9,11,13.5,16.5]
my = [60,60,60,60,60,60]
plt.scatter(mx,my,s=mSizeS,facecolors="white",
            edgecolor="white",zorder=zo)
plt.plot([5.5,17],
         [57,57],color="white",lw=2,zorder=zo)
i = 0
for i in range(len(mx)):
    plt.text(mx[i],my[i],mSize[i],
             fontsize=mSize[i]*18,color="#195905",
             zorder=zo,ha="center",va="center")
plt.text(11,55,"xG",color="white",
ha="center",va="center",zorder=zo,fontsize=16)

plt.scatter(47,60,s=100,facecolors="#b69c0e",edgecolor="black",zorder=zo)
plt.text(52,60," Goals",color="white",ha="center",va="center",zorder=zo,fontsize=16)

plt.scatter(47,57.5,s=100,facecolors="#d40808",edgecolor="black",zorder=zo)
plt.text(55,57.5," Missed Shots",color="white",ha="center",va="center",zorder=zo,fontsize=16)


plt.text(34,55,"@simplywink",color="white",ha="center",va="center",zorder=zo,fontsize=16)
plt.text(11,75,"Harry Kane",color="white",ha="center",va="center",zorder=zo,fontsize=16)
plt.text(11,72,"Tottenham Hotspur",color="white",ha="center",va="center",zorder=zo,fontsize=16)
plt.text(11,69,"Season : 15-20",color="white",ha="center",va="center",zorder=zo,fontsize=16)

plt.title("Harry Kane Open Play Shots")
plt.show()

# %%
data_19 = data[(data['year'] == 2019)]
data_OP = data_19[((data_19['situation'] == 'OpenPlay'))]
data_OPG = data_19[((data_19['result'] == 'Goal') & (data_19['situation'] == 'OpenPlay'))]
#data_OPG = data[((data['situation'] == 'OpenPlay'))]
data_OPNG = data_OP[((data_OP['result'] == 'BlockedShot') | (data_OP['result'] == 'ShotOnPost'))]
data_OPM = data_OP[((data_OP['result'] == 'MissedShots'))]
data_OPS = data_OP[((data_OP['result'] == 'SavedShot'))]

    
x_OPG = data_OPG['newX']
y_OPG = data_OPG['newY']
xG_OPG = data_OPG['xG']

x_OPNG = data_OPNG['newX']
y_OPNG = data_OPNG['newY']
xG_OPNG = data_OPNG['xG']
                    
x_OPM = data_OPM['newX']
y_OPM = data_OPM['newY']
xG_OPM = data_OPM['xG']

x_OPS = data_OPS['newX']
y_OPS = data_OPS['newY']
xG_OPS = data_OPS['xG']

#print(len(data_OPM))

zo = 12

draw_pitch("#242318","#faf0e6","vertical","half")
y1_OPG = [68 - i for i in y_OPG]
z1_OPG = [500 * i for i in xG_OPG] # This is to scale the "xG" values for plotting

y1_OPNG = [68 - i for i in y_OPNG]
z1_OPNG = [500 * i for i in xG_OPNG] # This is to scale the "xG" values for plotting

y1_OPM = [68 - i for i in y_OPM]
z1_OPM = [500 * i for i in xG_OPM] # This is to scale the "xG" values for plotting

y1_OPS = [68 - i for i in y_OPS]
z1_OPS = [500 * i for i in xG_OPS] # This is to scale the "xG" values for plotting


if len(data_OPG) > 0: 
    plt.scatter(y1_OPG,x_OPG,s=z1_OPG,c="#b69c0e",edgecolors="k",zorder=zo+1)
if len(data_OPS) > 0:
    plt.scatter(y1_OPS,x_OPS,s=z1_OPS,c="#BA7300",edgecolors="k",zorder=zo)
if len(data_OPM) > 0:
    plt.scatter(y1_OPM,x_OPM,s=z1_OPM,c="#d40808",edgecolors="k",zorder=zo)
if len(data_OPNG) > 0:
    plt.scatter(y1_OPNG,x_OPNG,s=z1_OPNG,c="#242318",edgecolors="white",zorder=zo)
     
        
mSize = [0.05,0.10,0.2,0.4,0.6,1] 
mSizeS = [500 * i for i in mSize]
mx = [5.5,7,9,11,13.5,16.5]
my = [60,60,60,60,60,60]
plt.scatter(mx,my,s=mSizeS,facecolors="white",
            edgecolor="white",zorder=zo)
plt.plot([5.5,17],
         [57,57],color="white",lw=2,zorder=zo)
i = 0
for i in range(len(mx)):
    plt.text(mx[i],my[i],mSize[i],
             fontsize=mSize[i]*18,color="#195905",
             zorder=zo,ha="center",va="center")
plt.text(11,55,"xG",color="white",
ha="center",va="center",zorder=zo,fontsize=16)

plt.scatter(47,60,s=100,facecolors="#b69c0e",edgecolor="black",zorder=zo)
plt.text(52.25,60," Goals",color="white",ha="center",va="center",zorder=zo,fontsize=16)

plt.scatter(47,57.5,s=100,facecolors="#d40808",edgecolor="black",zorder=zo)
plt.text(55.5,57.5," Missed Shots",color="white",ha="center",va="center",zorder=zo,fontsize=16)

plt.scatter(47,55.5,s=100,facecolors="#BA7300",edgecolor="black",zorder=zo)
plt.text(55,55.5," Saved Shots",color="white",ha="center",va="center",zorder=zo,fontsize=16)

plt.scatter(47,53.5,s=100,facecolors="#242318",edgecolor="white",zorder=zo)
plt.text(52.5,53.5," Others",color="white",ha="center",va="center",zorder=zo,fontsize=16)

plt.text(34,55,"@simplywink",color="white",ha="center",va="center",zorder=zo,fontsize=16)
plt.text(11,75,"Andrea Belotti",color="white",ha="center",va="center",zorder=zo,fontsize=16)
plt.text(11,72,"Torino",color="white",ha="center",va="center",zorder=zo,fontsize=16)
plt.text(11,69,"Season :19-20",color="white",ha="center",va="center",zorder=zo,fontsize=16)

#plt.title("Chris Open Play Shots")

#plt.savefig('Belotti1920.png',dpi=400,bbox_inches='tight',pad_inches = 1)

plt.show()

# %%
draw_pitch("#3e3e40","#faf0e6","vertical","half")
plt.hist2d(y1_OPShots,x_OPShots, range=[[-1,69],[49,105]],bins= [16,16], zorder = 2,cmap='hot')

#plt.clim(0,30)

plt.text(34,55,"@simplywink",color="white",ha="center",va="center",zorder=zo,fontsize=16)
plt.text(11,69,"Andrea Belotti",color="white",ha="center",va="center",zorder=zo,fontsize=16)
plt.text(13,66,"Torino",color="white",ha="center",va="center",zorder=zo,fontsize=16)
plt.text(13,63,"Seria A: 14-20",color="white",ha="center",va="center",zorder=zo,fontsize=16)

plt.colorbar()

#plt.savefig('Belottimap.png',dpi=400,bbox_inches='tight',pad_inches = 1)

plt.show()
